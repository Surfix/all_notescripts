# %%
import pandas as pd
import glob
import os
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# path = '/home/naheemadebisi/PhD/snow-analytics/Radar-Backscatter/pits_data/2020/SNEX20_TS_SP_preliminary_v6/pits/IDAHO-BoiseRiver/IDBRBO_20191218_1424'
# all_files = glob.glob(os.path.join(path, "*.csv"))
# for file in all_files:
#     if 'temperature' in file:
#         print(file)
#         temp = pd.read_csv(file, skiprows=10)
# temp

# %% [markdown]
# ## 2020

# %%
len(glob.glob('/home/naheemadebisi/PhD/snow-analytics/Radar-Backscatter/pits_data/2020/SNEX20_TS_SP_preliminary_v6/pits/*/*'))
# Out:
# 454

# %%
#read_csv
SWE_2020 = pd.read_csv('/home/naheemadebisi/PhD/snow-analytics/Radar-Backscatter/pits_data/2020/SNEX20_TS_SP_preliminary_v6/SNEX20_TS_SP_Summary_SWE_v01.csv')
#create column for mean temp
SWE_2020['Temp_mean'] = np.nan
SWE_2020
# Out:
#                      Location         Site                 PitID  \
# 0        American River Basin  Caples Lake  CAAMCL_20191220_1300
# 1        American River Basin  Caples Lake  CAAMCL_20200131_1215
# 2        American River Basin  Caples Lake  CAAMCL_20200214_1200
# 3        American River Basin  Caples Lake  CAAMCL_20200221_1200
# 4        American River Basin  Caples Lake  CAAMCL_20200228_1130
# ..                        ...          ...                   ...
# 446  Little Cottonwood Canyon      Atwater  UTLCAW_20200213_1510
# 447  Little Cottonwood Canyon      Atwater  UTLCAW_20200220_1350
# 448  Little Cottonwood Canyon      Atwater  UTLCAW_20200227_1145
# 449  Little Cottonwood Canyon      Atwater  UTLCAW_20200305_1230
# 450  Little Cottonwood Canyon      Atwater  UTLCAW_20200312_1248
#
#     Date/Local Standard Time UTM Zone  Easting (m)  Northing (m)  \
# 0           2019-12-20T13:00      10N       757216       4288787
# ...

# %%
#list all site directories
site_list = glob.glob('/home/naheemadebisi/PhD/snow-analytics/Radar-Backscatter/pits_data/2020/SNEX20_TS_SP_preliminary_v6/pits/*/*')

for site_dir in site_list:
    if os.path.isdir(site_dir):
        #extract pidID
        pitID = os.path.basename(site_dir)
        #check if the pitID exist in dataframe
        if pitID in SWE_2020['PitID'].values:
            #print(f'{site_dir} is found')
            #print(pitID)

            #list all csv file, select the temperature csv
            all_files = glob.glob(os.path.join(site_dir, "*.csv"))
            for file in all_files:
                if 'temperature' in file:
                    #print(file)
                    temp = pd.read_csv(file, skiprows=10)
            #find mean
            SWE_2020.loc[SWE_2020['PitID'] == pitID, 'Temp_mean'] = temp['Temperature (deg C)'].mean()
            #SWE_2020.loc[pitID, 'Temp_mean'] = temp['Temperature (deg C)'].mean()

# %%
SWE_2020.to_csv('/home/naheemadebisi/PhD/snow-analytics/Radar-Backscatter/pits_data/2020/SNEX20_TS_SP_preliminary_v6/SNEX20_TS_SP_Summary_SWE_v01_temp.csv')

# %%
SWE_2020
# Out:
#                      Location         Site                 PitID  \
# 0        American River Basin  Caples Lake  CAAMCL_20191220_1300
# 1        American River Basin  Caples Lake  CAAMCL_20200131_1215
# 2        American River Basin  Caples Lake  CAAMCL_20200214_1200
# 3        American River Basin  Caples Lake  CAAMCL_20200221_1200
# 4        American River Basin  Caples Lake  CAAMCL_20200228_1130
# ..                        ...          ...                   ...
# 446  Little Cottonwood Canyon      Atwater  UTLCAW_20200213_1510
# 447  Little Cottonwood Canyon      Atwater  UTLCAW_20200220_1350
# 448  Little Cottonwood Canyon      Atwater  UTLCAW_20200227_1145
# 449  Little Cottonwood Canyon      Atwater  UTLCAW_20200305_1230
# 450  Little Cottonwood Canyon      Atwater  UTLCAW_20200312_1248
#
#     Date/Local Standard Time UTM Zone  Easting (m)  Northing (m)  \
# 0           2019-12-20T13:00      10N       757216       4288787
# ...

# %% [markdown]
# ## 2021

# %%
len(glob.glob('/home/naheemadebisi/PhD/snow-analytics/Radar-Backscatter/pits_data/2021/SNEX21_TS_SP_preliminary_v1/pits/*/*'))
# Out:
# 248

# %%
#read_csv
SWE_2021 = pd.read_csv('/home/naheemadebisi/PhD/snow-analytics/Radar-Backscatter/pits_data/2021/SNEX21_TS_SP_preliminary_v1/SNEX21_TS_SP_Summary_SWE_v01.csv')
#create column for mean temp
SWE_2021['Temp_mean'] = np.nan
SWE_2021
# Out:
#                      Location         Site                 PitID  \
# 0           Boise River Basin  Bogus Lower  IDBRBL_20201116_1100
# 1           Boise River Basin  Bogus Lower  IDBRBL_20201123_1542
# 2           Boise River Basin  Bogus Lower  IDBRBL_20201201_1149
# 3           Boise River Basin  Bogus Lower  IDBRBL_20201209_1200
# 4           Boise River Basin  Bogus Lower  IDBRBL_20201216_1430
# ..                        ...          ...                   ...
# 238  Little Cottonwood Canyon      Atwater  UTLCAW_20210310_0930
# 239  Little Cottonwood Canyon      Atwater  UTLCAW_20210317_0850
# 240  Little Cottonwood Canyon      Atwater  UTLCAW_20210322_0950
# 241  Little Cottonwood Canyon      Atwater  UTLCAW_20210507_0910
# 242  Little Cottonwood Canyon      Atwater  UTLCAW_20210517_1120
#
#     Date/Local Standard Time UTM Zone  Easting (m)  Northing (m)  \
# 0           2020-11-16T11:00      11N       573175       4845307
# ...

# %%
#list all site directories
site_list = glob.glob('/home/naheemadebisi/PhD/snow-analytics/Radar-Backscatter/pits_data/2021/SNEX21_TS_SP_preliminary_v1/pits/*/*')

for site_dir in site_list:
    if os.path.isdir(site_dir):
        #extract pidID
        pitID = os.path.basename(site_dir).split('_S')[0]
        #check if the pitID exist in dataframe
        if pitID in SWE_2021['PitID'].values:
            #print(f'{site_dir} is found')
            #print(pitID)

            #list all csv file, select the temperature csv
            all_files = glob.glob(os.path.join(site_dir, "*.csv"))
            for file in all_files:
                if 'temperature' in file:
                    #print(file)
                    temp = pd.read_csv(file, skiprows=10)
            #find mean
            SWE_2021.loc[SWE_2021['PitID'] == pitID, 'Temp_mean'] = temp['Temperature (deg C)'].mean()
            #SWE_2020.loc[pitID, 'Temp_mean'] = temp['Temperature (deg C)'].mean()

# %%
SWE_2021
# Out:
#                      Location         Site                 PitID  \
# 0           Boise River Basin  Bogus Lower  IDBRBL_20201116_1100
# 1           Boise River Basin  Bogus Lower  IDBRBL_20201123_1542
# 2           Boise River Basin  Bogus Lower  IDBRBL_20201201_1149
# 3           Boise River Basin  Bogus Lower  IDBRBL_20201209_1200
# 4           Boise River Basin  Bogus Lower  IDBRBL_20201216_1430
# ..                        ...          ...                   ...
# 238  Little Cottonwood Canyon      Atwater  UTLCAW_20210310_0930
# 239  Little Cottonwood Canyon      Atwater  UTLCAW_20210317_0850
# 240  Little Cottonwood Canyon      Atwater  UTLCAW_20210322_0950
# 241  Little Cottonwood Canyon      Atwater  UTLCAW_20210507_0910
# 242  Little Cottonwood Canyon      Atwater  UTLCAW_20210517_1120
#
#     Date/Local Standard Time UTM Zone  Easting (m)  Northing (m)  \
# 0           2020-11-16T11:00      11N       573175       4845307
# ...

# %%
SWE_2021.to_csv('/home/naheemadebisi/PhD/snow-analytics/Radar-Backscatter/pits_data/2021/SNEX21_TS_SP_preliminary_v1/SNEX21_TS_SP_Summary_SWE_v01_temp.csv')
