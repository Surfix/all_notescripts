# %% [markdown]
# In this notebook, I validated UCLWA snow depth using qsi data. The 250m resolution UCLWA snow depth raster file was vectorize to polygon and the pixel value is the VALUE column. Zonal Statistics operation with vectorized UCLWA polygon as input vector was performed to compute count, mean and standandard deviation of qsi pixels within the UCLWA polygon. The resulting file is saved as a csv for each sites using "Sitename_DATE_

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as sps
from scipy.stats import ttest_rel
from sklearn.metrics import r2_score

# %% [markdown]
# ## USCOCP_20210319

# %%
#read the file for each sites
USCOCP_20210319 = pd.read_csv("../data_results/snow_depth/extracted_values/USCOCP_20210319_UCLWA_QSI.csv").dropna()
USCOCP_20210319.rename(columns= {'VALUE':'UCLWA SD', "_mean": "QSI_mean SD", "_stdev": "QSI_stdev"}, inplace= True)
#select only rows with representative pixel values
USCOCP_20210319 = USCOCP_20210319[USCOCP_20210319["_count"] > 250000]
USCOCP_20210319.describe()
# Out:
#          UCLWA SD         _count  QSI_mean SD   QSI_stdev
# count  123.000000     123.000000   123.000000  123.000000
# mean     0.399202  647158.520325     1.453859    0.422493
# std      0.203006  139387.227244     0.179630    0.242915
# min      0.005600  254951.000000     0.912101    0.195384
# 25%      0.235200  591171.500000     1.371492    0.276466
# 50%      0.434600  725875.000000     1.434202    0.336455
# 75%      0.543500  737043.500000     1.547074    0.472531
# max      1.018400  737547.000000     1.991068    1.374860

# %%
ax = sns.regplot(x="QSI_mean SD", y="UCLWA SD", data=USCOCP_20210319, line_kws={'color': 'red'})

# %%
sns.jointplot(x="QSI_mean SD", y="UCLWA SD", data=USCOCP_20210319)

# %%
ttest_rel(USCOCP_20210319['QSI_mean SD'], USCOCP_20210319['UCLWA SD'], nan_policy='omit')
# Out:
# Ttest_relResult(statistic=45.65165205367765, pvalue=1.5036677947014724e-78)

# %%
USCOCP_20210319["QSI_mean SD"].corr(USCOCP_20210319["UCLWA SD"])
# Out:
# 0.10738063386514231

# %% [markdown]
# ## USCOFR_20200211

# %% [markdown]
# UCLWA raster gives all zeros

# %%
# #read the file for each sites
# USCOFR_20200211 = pd.read_csv("../data_results/snow_depth/extracted_values/USCOFR_20200211_UCLWA_QSI.csv").dropna()
# #select only rows with representative pixel values
# USCOFR_20200211 = USCOFR_20200211[USCOFR_20200211["_count"] > 1500000]
# USCOFR_20200211.rename(columns= {'VALUE':'UCLWA SD', "_mean": "QSI_mean SD", "_stdev": "QSI_stdev"}, inplace= True)
# #select only rows with representative pixel values
# #USCOFR_20200211 = USCOFR_20210319[USCOFR_20210319["_count"] > 250000]
# USCOFR_20200211.describe()

# %% [markdown]
# ## USCOFR_20210319

# %%
#read the file for each sites
USCOFR_20210319 = pd.read_csv("../data_results/snow_depth/extracted_values/USCOFR_20210319_UCLWA_QSI.csv").dropna()
USCOFR_20210319.rename(columns= {'VALUE':'UCLWA SD', "_mean": "QSI_mean SD", "_stdev": "QSI_stdev"}, inplace= True)
#select only rows with representative pixel values
USCOFR_20210319 = USCOFR_20210319[USCOFR_20210319["_count"] > 250000]
USCOFR_20210319.describe()
# Out:
#          UCLWA SD         _count  QSI_mean SD   QSI_stdev
# count  336.000000     336.000000   336.000000  336.000000
# mean     0.097727  717451.675595     0.871938    0.270681
# std      0.092211   75715.845518     0.245506    0.201263
# min      0.000000  254204.000000     0.460185    0.143398
# 25%      0.009350  734927.750000     0.677619    0.191337
# 50%      0.085000  742920.500000     0.825654    0.211441
# 75%      0.151550  744233.000000     1.020146    0.243858
# max      0.527000  744672.000000     2.123587    1.925801

# %%
ax = sns.regplot(x="QSI_mean SD", y="UCLWA SD", data=USCOFR_20210319, line_kws={'color': 'red'})

# %%
sns.jointplot(x="QSI_mean SD", y="UCLWA SD", data=USCOFR_20210319)

# %%
ttest_rel(USCOFR_20210319['QSI_mean SD'], USCOFR_20210319['UCLWA SD'], nan_policy='omit')
# Out:
# Ttest_relResult(statistic=54.37492286253596, pvalue=2.7597258160016235e-168)

# %%
USCOFR_20210319["QSI_mean SD"].corr(USCOFR_20210319["UCLWA SD"])
# Out:
# 0.014535107628190394

# %% [markdown]
# ## USIDBN_20200218

# %%
#read the file for each sites
USIDBN_20200218 = pd.read_csv("../data_results/snow_depth/extracted_values/USIDBN_20200218_UCLWA_QSI.csv").dropna()
USIDBN_20200218.rename(columns= {'VALUE':'UCLWA SD', "_mean": "QSI_mean SD", "_stdev": "QSI_stdev"}, inplace= True)
#select only rows with representative pixel values
USIDBN_20200218 = USIDBN_20200218[USIDBN_20200218["_count"] > 250000]
USIDBN_20200218.describe()
# Out:
#          UCLWA SD         _count          _sum  QSI_mean SD
# count  971.000000     971.000000  9.710000e+02   971.000000
# mean     1.287040  679749.186406  1.030529e+06     1.514309
# std      0.524376   59871.312553  2.469122e+05     0.334323
# min      0.000000  265660.000000  2.338237e+05     0.596587
# 25%      0.913300  694174.500000  8.707481e+05     1.277202
# 50%      1.300800  695132.000000  1.010629e+06     1.480296
# 75%      1.655000  695451.000000  1.190362e+06     1.730745
# max      2.986200  696356.000000  1.801908e+06     2.685785

# %%
ax = sns.regplot(x="QSI_mean SD", y="UCLWA SD", data=USIDBN_20200218, line_kws={'color': 'red'})

# %%
sns.jointplot(x="QSI_mean SD", y="UCLWA SD", data=USIDBN_20200218)

# %%
ttest_rel(USIDBN_20200218['QSI_mean SD'], USIDBN_20200218['UCLWA SD'], nan_policy='omit')
# Out:
# Ttest_relResult(statistic=13.459678994947318, pvalue=5.50244244090337e-38)

# %%
USIDBN_20200218["QSI_mean SD"].corr(USIDBN_20200218["UCLWA SD"])
# Out:
# 0.31344568830743874

# %% [markdown]
# ## USIDBN_20210315

# %%
#read the file for each sites
USIDBN_20210315 = pd.read_csv("../data_results/snow_depth/extracted_values/USIDBN_20210315_UCLWA_QSI.csv").dropna()
USIDBN_20210315.rename(columns= {'VALUE':'UCLWA SD', "_mean": "QSI_mean SD", "_stdev": "QSI_stdev"}, inplace= True)
#select only rows with representative pixel values
USIDBN_20210315 = USIDBN_20210315[USIDBN_20210315["_count"] > 200000]
USIDBN_20210315.describe()
# Out:
#          UCLWA SD         _count  QSI_mean SD   QSI_stdev
# count  982.000000     982.000000   982.000000  982.000000
# mean     1.314343  670202.329939     1.485653    0.340714
# std      0.541637   77835.632029     0.339550    0.143914
# min      0.002000  201527.000000     0.602600    0.108968
# 25%      0.974500  688795.000000     1.243041    0.236399
# 50%      1.315400  694765.000000     1.462572    0.313590
# 75%      1.708250  695283.500000     1.699541    0.410913
# max      2.744000  696356.000000     2.608404    1.047727

# %%
ax = sns.regplot(x="QSI_mean SD", y="UCLWA SD", data=USIDBN_20210315, line_kws={'color': 'red'})

# %%
sns.jointplot(x="QSI_mean SD", y="UCLWA SD", data=USIDBN_20210315)

# %%
ttest_rel(USIDBN_20210315['QSI_mean SD'], USIDBN_20210315['UCLWA SD'], nan_policy='omit')
# Out:
# Ttest_relResult(statistic=9.262478709601952, pvalue=1.226375904337292e-19)

# %%
USIDBN_20210315["QSI_mean SD"].corr(USIDBN_20210315["UCLWA SD"])
# Out:
# 0.19779004259834312

# %% [markdown]
# ## USIDC_20200219

# %% [markdown]
# All zeros

# %%
# #read the file for each sites
# USIDC_20200219 = pd.read_csv("../data_results/snow_depth/extracted_values/USIDC_20200219_UCLWA_QSI.csv").dropna()
# USIDC_20200219.rename(columns= {'VALUE':'UCLWA SD', "_mean": "QSI_mean SD", "_stdev": "QSI_stdev"}, inplace= True)
# #select only rows with representative pixel values
# USIDC_20200219= USIDC_20200219[USIDC_20200219["_count"] > 200000]
# USIDC_20200219.describe()

# %% [markdown]
# ## USIDMC_20200209

# %%
#read the file for each sites
USIDMC_20200209 = pd.read_csv("../data_results/snow_depth/extracted_values/USIDMC_20200209_UCLWA_QSI.csv").dropna()
USIDMC_20200209.rename(columns= {'VALUE':'UCLWA SD', "_mean": "QSI_mean SD", "_stdev": "QSI_stdev"}, inplace= True)
#select only rows with representative pixel values
USIDMC_20200209= USIDMC_20200209[USIDMC_20200209["_count"] > 200000]
USIDMC_20200209.describe()
# Out:
#          UCLWA SD         _count  QSI_mean SD   QSI_stdev
# count  208.000000     208.000000   208.000000  208.000000
# mean     1.558842  655315.778846     1.791280    0.318730
# std      0.488073  106249.242751     0.277258    0.052256
# min      0.464400  212576.000000     1.028538    0.160759
# 25%      1.224750  690634.250000     1.635387    0.289332
# 50%      1.641300  698965.000000     1.826638    0.316851
# 75%      1.932150  699127.500000     1.998965    0.349934
# max      2.614200  699413.000000     2.309724    0.548388

# %%
ax = sns.regplot(x="QSI_mean SD", y="UCLWA SD", data=USIDMC_20200209, line_kws={'color': 'red'})

# %%
ttest_rel(USIDMC_20200209['QSI_mean SD'], USIDMC_20200209['UCLWA SD'], nan_policy='omit')
# Out:
# Ttest_relResult(statistic=6.355529617096861, pvalue=1.30101171003326e-09)

# %%
USIDMC_20200209["QSI_mean SD"].corr(USIDMC_20200209["UCLWA SD"])
# Out:
# 0.13625898483136467

# %% [markdown]
# ## USIDMC_20210315

# %%
#read the file for each sites
USIDMC_20210315 = pd.read_csv("../data_results/snow_depth/extracted_values/USIDMC_20210315_UCLWA_QSI.csv").dropna()
USIDMC_20210315.rename(columns= {'VALUE':'UCLWA SD', "_mean": "QSI_mean SD", "_stdev": "QSI_stdev"}, inplace= True)
#select only rows with representative pixel values
USIDMC_20210315= USIDMC_20210315[USIDMC_20210315["_count"] > 200000]
USIDMC_20210315.describe()
# Out:
#          UCLWA SD         _count  QSI_mean SD   QSI_stdev
# count  208.000000     208.000000   208.000000  208.000000
# mean     1.535124  650712.543269     1.606697    0.371909
# std      0.446830  107232.048524     0.360750    0.072979
# min      0.311000  212573.000000     0.749465    0.190081
# 25%      1.196300  676000.000000     1.330915    0.327327
# 50%      1.598500  698127.000000     1.639409    0.370313
# 75%      1.865800  698923.250000     1.920259    0.411938
# max      2.507600  699335.000000     2.266668    0.793835

# %%
ax = sns.regplot(x="QSI_mean SD", y="UCLWA SD", data=USIDMC_20210315, line_kws={'color': 'red'})

# %%
ttest_rel(USIDMC_20210315['QSI_mean SD'], USIDMC_20210315['UCLWA SD'], nan_policy='omit')
# Out:
# Ttest_relResult(statistic=2.0341837800312264, pvalue=0.043208640862854385)

# %%
USIDMC_20210315["QSI_mean SD"].corr(USIDMC_20210315["UCLWA SD"])
# Out:
# 0.22424210233723993

# %% [markdown]
# ## USUTLC_20210318

# %%
#read the file for each sites
USUTLC_20210318 = pd.read_csv("../data_results/snow_depth/extracted_values/USUTLC_20210318_UCLWA_QSI.csv").dropna()
USUTLC_20210318.rename(columns= {'VALUE':'UCLWA SD', "_mean": "QSI_mean SD", "_stdev": "QSI_stdev"}, inplace= True)
#select only rows with representative pixel values
USUTLC_20210318= USUTLC_20210318[USUTLC_20210318["_count"] > 200000]
USUTLC_20210318.describe()
# Out:
#          UCLWA SD         _count  QSI_mean SD   QSI_stdev
# count  165.000000     165.000000   165.000000  165.000000
# mean     0.054105  657480.854545     1.819943    0.729547
# std      0.080138  137693.665266     0.312887    0.282150
# min      0.000000  200294.000000     0.975716    0.313847
# 25%      0.002400  654038.000000     1.626613    0.504352
# 50%      0.018000  728541.000000     1.767896    0.672681
# 75%      0.074800  735397.000000     2.017308    0.878545
# max      0.522800  737064.000000     2.745196    1.671869

# %%
ax = sns.regplot(x="QSI_mean SD", y="UCLWA SD", data=USUTLC_20210318, line_kws={'color': 'red'})

# %%
ttest_rel(USUTLC_20210318['QSI_mean SD'], USUTLC_20210318['UCLWA SD'], nan_policy='omit')
# Out:
# Ttest_relResult(statistic=69.68914430483102, pvalue=9.04437082298318e-124)

# %%
USUTLC_20210318["QSI_mean SD"].corr(USUTLC_20210318["UCLWA SD"])
# Out:
# -0.032269756295113125

# %%
# #all plots in one figure
# fig, axs = plt.subplots(nrows = 3, ncols = 3, figsize = (13,10), constrained_layout = True)
# #
# sns.regplot(x="QSI_mean SD", y="SNODAS SD", data=USCOCP_20210319, line_kws={'color': 'red'}, ax = axs[0,0])
# axs[0,0].set_title('Cameron Pass, 2021')
# axs[0,0].legend(labels=["r = {:.2f}".format(USCOCP_20210319["QSI_mean SD"].corr(USCOCP_20210319["SNODAS SD"]))])

# sns.regplot(x="QSI_mean SD", y="SNODAS SD", data=USCOFR_20200211, line_kws={'color': 'red'}, ax = axs[0,1])
# axs[0,1].set_title('Fraser, 2020')
# axs[0,1].legend(labels=["r = {:.2f}".format(USCOFR_20200211["QSI_mean SD"].corr(USCOFR_20200211["SNODAS SD"]))])

# sns.regplot(x="QSI_mean SD", y="SNODAS SD", data=USCOFR_20210319, line_kws={'color': 'red'}, ax = axs[0,2])
# axs[0,2].set_title('Fraser, 2021')
# axs[0,2].legend(labels=["r = {:.2f}".format(USCOFR_20210319["QSI_mean SD"].corr(USCOFR_20210319["SNODAS SD"]))])

# sns.regplot(x="QSI_mean SD", y="SNODAS SD", data=USIDBN_20200218, line_kws={'color': 'red'}, ax = axs[1,0])
# axs[1,0].set_title('Banner, 2020')
# axs[1,0].legend(labels=["r = {:.2f}".format(USIDBN_20200218["QSI_mean SD"].corr(USIDBN_20200218["SNODAS SD"]))])

# sns.regplot(x="QSI_mean SD", y="SNODAS SD", data=USIDBN_20210315, line_kws={'color': 'red'}, ax = axs[1,1])
# axs[1,1].set_title('Banner, 2021')
# axs[1,1].legend(labels=["r = {:.2f}".format(USIDBN_20210315["QSI_mean SD"].corr(USIDBN_20210315["SNODAS SD"]))])

# sns.regplot(x="QSI_mean SD", y="SNODAS SD", data=USIDC_20200219, line_kws={'color': 'red'}, ax = axs[1,2])
# axs[1,2].set_title('Dry Creke, 2020')
# axs[1,2].legend(labels=["r = {:.2f}".format(USIDC_20200219["QSI_mean SD"].corr(USIDC_20200219["SNODAS SD"]))])

# sns.regplot(x="QSI_mean SD", y="SNODAS SD", data=USIDMC_20200209, line_kws={'color': 'red'}, ax = axs[2,0])
# axs[2,0].set_title('Mores Creke, 2020')
# axs[2,0].legend(labels=["r = {:.2f}".format(USIDMC_20200209["QSI_mean SD"].corr(USIDMC_20200209["SNODAS SD"]))])

# sns.regplot(x="QSI_mean SD", y="SNODAS SD", data=USIDMC_20210315, line_kws={'color': 'red'}, ax = axs[2,1])
# axs[2,1].set_title('Mores Creke, 2021')
# axs[2,1].legend(labels=["r = {:.2f}".format(USIDMC_20210315["QSI_mean SD"].corr(USIDMC_20210315["SNODAS SD"]))])

# sns.regplot(x="QSI_mean SD", y="SNODAS SD", data=USUTLC_20210318, line_kws={'color': 'red'}, ax = axs[2,2])
# axs[2,2].set_title('Little Cottonwood, 2021')
# axs[2,2].legend(labels=["r = {:.2f}".format(USUTLC_20210318["QSI_mean SD"].corr(USUTLC_20210318["SNODAS SD"]))])

# %%
#all plots in one figure
fig, axs = plt.subplots(nrows = 3, ncols = 3, figsize = (13,10), constrained_layout = True)

sns.scatterplot(x="QSI_mean SD", y="UCLWA SD", data=USCOCP_20210319, ax = axs[0,0])
axs[0,0].set_title('Cameron Pass, 2021')
sns.lineplot(x="QSI_mean SD", y="QSI_mean SD", data=USCOCP_20210319, ax = axs[0,0], color = 'r')
#axs[0,0].legend(labels=["r = {:.2f}".format(USCOCP_20210319["QSI_mean SD"].corr(USCOCP_20210319["SNODAS SD"]))])

# sns.scatterplot(x="QSI_mean SD", y="UCLWA SD", data=USCOFR_20200211, ax = axs[0,1])
# axs[0,1].set_title('Fraser, 2020')
# sns.lineplot(x="QSI_mean SD", y="QSI_mean SD", data=USCOFR_20200211, ax = axs[0,1], color = 'r')
# #axs[0,1].legend(labels=["r = {:.2f}".format(USCOFR_20200211["QSI_mean SD"].corr(USCOFR_20200211["SNODAS SD"]))])

sns.scatterplot(x="QSI_mean SD", y="UCLWA SD", data=USCOFR_20210319, ax = axs[0,2])
axs[0,2].set_title('Fraser, 2021')
sns.lineplot(x="QSI_mean SD", y="QSI_mean SD", data=USCOFR_20210319, ax = axs[0,2], color = 'r')
#axs[0,2].legend(labels=["r = {:.2f}".format(USCOFR_20210319["QSI_mean SD"].corr(USCOFR_20210319["SNODAS SD"]))])

sns.scatterplot(x="QSI_mean SD", y="UCLWA SD", data=USIDBN_20200218, ax = axs[1,0])
axs[1,0].set_title('Banner, 2020')
sns.lineplot(x="QSI_mean SD", y="QSI_mean SD", data=USIDBN_20200218, ax = axs[1,0], color = 'r')
#axs[1,0].legend(labels=["r = {:.2f}".format(USIDBN_20200218["QSI_mean SD"].corr(USIDBN_20200218["SNODAS SD"]))])

sns.scatterplot(x="QSI_mean SD", y="UCLWA SD", data=USIDBN_20210315, ax = axs[1,1])
axs[1,1].set_title('Banner, 2021')
sns.lineplot(x="QSI_mean SD", y="QSI_mean SD", data=USIDBN_20210315, ax = axs[1,1], color = 'r')
#axs[1,1].legend(labels=["r = {:.2f}".format(USIDBN_20210315["QSI_mean SD"].corr(USIDBN_20210315["SNODAS SD"]))])

# sns.scatterplot(x="QSI_mean SD", y="UCLWA SD", data=USIDC_20200219, ax = axs[1,2])
# axs[1,2].set_title('Dry Creke, 2020')
# sns.lineplot(x="QSI_mean SD", y="QSI_mean SD", data=USIDC_20200219, ax = axs[1,2], color = 'r')
# #axs[1,2].legend(labels=["r = {:.2f}".format(USIDC_20200219["QSI_mean SD"].corr(USIDC_20200219["SNODAS SD"]))])

sns.scatterplot(x="QSI_mean SD", y="UCLWA SD", data=USIDMC_20200209, ax = axs[2,0])
axs[2,0].set_title('Mores Creke, 2020')
sns.lineplot(x="QSI_mean SD", y="QSI_mean SD", data=USIDMC_20200209, ax = axs[2,0], color = 'r')
#axs[2,0].legend(labels=["r = {:.2f}".format(USIDMC_20200209["QSI_mean SD"].corr(USIDMC_20200209["SNODAS SD"]))])

sns.scatterplot(x="QSI_mean SD", y="UCLWA SD", data=USIDMC_20210315, ax = axs[2,1])
axs[2,1].set_title('Mores Creke, 2021')
sns.lineplot(x="QSI_mean SD", y="QSI_mean SD", data=USIDMC_20210315, ax = axs[2,1], color = 'r')
#axs[2,1].legend(labels=["r = {:.2f}".format(USIDMC_20210315["QSI_mean SD"].corr(USIDMC_20210315["SNODAS SD"]))])

sns.scatterplot(x="QSI_mean SD", y="UCLWA SD", data=USUTLC_20210318, ax = axs[2,2])
axs[2,2].set_title('Little Cottonwood, 2021')
sns.lineplot(x="QSI_mean SD", y="QSI_mean SD", data=USUTLC_20210318, ax = axs[2,2], color = 'r')
#axs[2,2].legend(labels=["r = {:.2f}".format(USUTLC_20210318["QSI_mean SD"].corr(USUTLC_20210318["SNODAS SD"]))])
# Out:
# <AxesSubplot:title={'center':'Little Cottonwood, 2021'}, xlabel='QSI_mean SD', ylabel='UCLWA SD'>
